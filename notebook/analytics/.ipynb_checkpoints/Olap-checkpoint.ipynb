# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import psycopg2
import pandas as pd
import psycopg2.extras
import seaborn as sns
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
class PostgresConnection(object):
    def __init__(self):
        self.connection = psycopg2.connect(database="ecomdb",
                                           user = "postgres",
                                           password = "hai",
                                           host = "127.0.0.1",
                                           port = "5432")

    def getConnection(self):
        print("successfully connected to database")
        return self.connection

# %%
con = PostgresConnection().getConnection()
# Out:
# successfully connected to database

# %% [markdown]
# # Q1: Find the division wise total_sale_price joining fact table and respective dimension table

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT s.division, SUM(t.total_price) " \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.store_dim s on s.store_key=t.store_key " \
                "GROUP BY CUBE(s.division) " \
                "ORDER BY s.division "
cur.execute(select_stmt)
records = cur.fetchall()
# Out:
# successfully connected to database

# %%
records
# Out:
# [('BARISAL', Decimal('7520343.75')),
#  ('CHITTAGONG', Decimal('19763595.00')),
#  ('DHAKA', Decimal('40764619.75')),
#  ('KHULNA', Decimal('11311610.50')),
#  ('RAJSHAHI', Decimal('12099196.00')),
#  ('RANGPUR', Decimal('8429836.50')),
#  ('SYLHET', Decimal('5512234.25')),
#  (None, Decimal('105401435.75'))]

# %%
df_q1 = pd.DataFrame(records, columns=['division', 'sales'])
df_q1
# Out:
#      division         sales
# 0     BARISAL    7520343.75
# 1  CHITTAGONG   19763595.00
# 2       DHAKA   40764619.75
# 3      KHULNA   11311610.50
# 4    RAJSHAHI   12099196.00
# 5     RANGPUR    8429836.50
# 6      SYLHET    5512234.25
# 7        None  105401435.75

# %%
#we need to remove the total row 
df_q1 =df_q1.drop(7)

# %%
df_q1
# Out:
#      division        sales
# 0     BARISAL   7520343.75
# 1  CHITTAGONG  19763595.00
# 2       DHAKA  40764619.75
# 3      KHULNA  11311610.50
# 4    RAJSHAHI  12099196.00
# 5     RANGPUR   8429836.50
# 6      SYLHET   5512234.25

# %%
#The sales are stored as string. So we need to typecast them. 
def changetype(x):
    x['sales']=x['sales'].astype('float64')

# %%
#We will change all value of the df_q1 list
changetype(df_q1)

# %%
df_q1
# Out:
#      division        sales
# 0     BARISAL   7520343.75
# 1  CHITTAGONG  19763595.00
# 2       DHAKA  40764619.75
# 3      KHULNA  11311610.50
# 4    RAJSHAHI  12099196.00
# 5     RANGPUR   8429836.50
# 6      SYLHET   5512234.25

# %%
#This is not mandatory. But if we won't use then label 0 1 2 ... will show instead of divisoin name
#So we need to set index as not 0, 1, 2 but division name 
df_q1=df_q1.set_index(['division'])
df_q1
# Out:
#                   sales
# division
# BARISAL      7520343.75
# CHITTAGONG  19763595.00
# DHAKA       40764619.75
# KHULNA      11311610.50
# RAJSHAHI    12099196.00
# RANGPUR      8429836.50
# SYLHET       5512234.25

# %%
df_q1.plot.pie(y='sales')
# Out:
# <Axes: ylabel='sales'>

# %%
plt.figure(figsize=(10,5))
df_q1.plot.bar(y='sales')
# Out:
# <Axes: xlabel='division'>

# %% [markdown]
# # Q1: Find the year wise total_sale_price joining fact table and respective dimension table

# %%
#Now we want to sort by year wise 
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT s.year, SUM(t.total_price) " \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.time_dim s on s.time_key=t.time_key " \
                "GROUP BY CUBE(s.year) " \
                "ORDER BY s.year "
cur.execute(select_stmt)
records = cur.fetchall()
# Out:
# successfully connected to database

# %%
records
# Out:
# [(2014, Decimal('14334731.25')),
#  (2015, Decimal('15095720.25')),
#  (2016, Decimal('14976508.25')),
#  (2017, Decimal('15015806.00')),
#  (2018, Decimal('15108197.25')),
#  (2019, Decimal('14949510.25')),
#  (2020, Decimal('15037190.25')),
#  (2021, Decimal('883772.25')),
#  (None, Decimal('105401435.75'))]

# %%
df_q1 = pd.DataFrame(records, columns=['year', 'sales'])
df_q1
# Out:
#      year         sales
# 0  2014.0   14334731.25
# 1  2015.0   15095720.25
# 2  2016.0   14976508.25
# 3  2017.0   15015806.00
# 4  2018.0   15108197.25
# 5  2019.0   14949510.25
# 6  2020.0   15037190.25
# 7  2021.0     883772.25
# 8     NaN  105401435.75

# %%
#we need to remove the total row 
df_q1 =df_q1.drop(8)
df_q1
# Out:
#      year        sales
# 0  2014.0  14334731.25
# 1  2015.0  15095720.25
# 2  2016.0  14976508.25
# 3  2017.0  15015806.00
# 4  2018.0  15108197.25
# 5  2019.0  14949510.25
# 6  2020.0  15037190.25
# 7  2021.0    883772.25

# %%
#The sales are stored as string. So we need to typecast them. 
def changetype(x):
    x['sales']=x['sales'].astype('float64')

# %%
#We will change all value of the df_q1 list
changetype(df_q1)
df_q1
# Out:
#      year        sales
# 0  2014.0  14334731.25
# 1  2015.0  15095720.25
# 2  2016.0  14976508.25
# 3  2017.0  15015806.00
# 4  2018.0  15108197.25
# 5  2019.0  14949510.25
# 6  2020.0  15037190.25
# 7  2021.0    883772.25

# %%
#This is not mandatory. But if we won't use then label 0 1 2 ... will show instead of divisoin name
#So we need to set index as not 0, 1, 2 but division name 
df_q1=df_q1.set_index(['year'])
df_q1
# Out:
#               sales
# year
# 2014.0  14334731.25
# 2015.0  15095720.25
# 2016.0  14976508.25
# 2017.0  15015806.00
# 2018.0  15108197.25
# 2019.0  14949510.25
# 2020.0  15037190.25
# 2021.0    883772.25

# %%
df_q1.plot.pie(y='sales')
# Out:
# <Axes: ylabel='sales'>

# %%
plt.figure(figsize=(10,5))
df_q1.plot.bar(y='sales')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# # Q1: Find the district wise total_sale_price joining fact table and respective dimension table

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT s.district, SUM(t.total_price) " \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.store_dim s on s.store_key=t.store_key " \
            "GROUP BY CUBE(s.district) " \
                "ORDER BY SUM(t.total_price)"
cur.execute(select_stmt)
records = cur.fetchall()
# Out:
# successfully connected to database

# %%
records
# Out:
# [('MEHERPUR', Decimal('436755.00')),
#  ('NARAIL', Decimal('440698.75')),
#  ('CHUADANGA', Decimal('563909.75')),
#  ('JHALOKATI', Decimal('570807.25')),
#  ('MAGURA', Decimal('577543.25')),
#  ('MADARIPUR', Decimal('601530.50')),
#  ('GAZIPUR', Decimal('722286.25')),
#  ('LAKSHMIPUR', Decimal('729909.25')),
#  ('THAKURGAON', Decimal('729934.25')),
#  ('GOPALGANJ', Decimal('731312.75')),
#  ('LALMONIRHAT', Decimal('732387.00')),
#  ('NARAYANGANJ', Decimal('733546.50')),
#  ('SHERPUR', Decimal('733712.00')),
#  ('JOYPURHAT', Decimal('735378.50')),
#  ('RAJBARI', Decimal('736393.00')),
#  ('PANCHAGARH', Decimal('736777.25')),
#  ('CHAPAI NABABGANJ', Decimal('739447.50')),
#  ('FENI', Decimal('847873.50')),
#  ('SHARIATPUR', Decimal('855565.75')),
#  ('NILPHAMARI', Decimal('862774.75')),
#  ('MUNSHIGANJ', Decimal('866631.25')),
#  ('BARGUNA', Decimal('869041.00')),
#  ('JHENAIDAH', Decimal('869991.25')),
#  ('KUSHTIA', Decimal('871240.50')),
#  ('NARSINGDI', Decimal('885864.75')),
# ...

# %%
dist= pd.DataFrame(list(records), columns=['district', 'sales'])
dist
dist=dist.dropna()
changetype(dist)
dist.dtypes
# Out:
# district     object
# sales       float64
# dtype: object

# %%
plt.figure(figsize = (15, 15))
barlist=plt.barh(dist['district'],dist['sales'], height=0.5)
barlist[63].set_color('g')
plt.title('District Wise Sales Graph')
plt.xlabel('Sales')
plt.ylabel('District')
plt.show()

# %% [markdown]
# # Q1: Find the month wise total_sale_price joining fact table and respective dimension table

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
#month are stored as number januray is 1 november is 11 and so on
select_stmt = "SELECT tim.month, SUM(t.total_price) " \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.store_dim s on s.store_key=t.store_key " \
            "JOIN ecomdb_star_schema.time_dim tim on tim.time_key=t.time_key "\
"GROUP BY CUBE(tim.month) " \
                "ORDER BY tim.month"
cur.execute(select_stmt)
records = cur.fetchall()
records
month= pd.DataFrame(list(records), columns=['month', 'sales'])
month
month=month.dropna()
month
# Out:
# successfully connected to database
#     month       sales
# 0     1.0  9042244.00
# 1     2.0  8073877.50
# 2     3.0  8939152.00
# 3     4.0  8504634.75
# 4     5.0  9078002.50
# 5     6.0  8556853.00
# 6     7.0  9046580.00
# 7     8.0  8929475.25
# 8     9.0  8724326.50
# 9    10.0  8902783.75
# 10   11.0  8680026.00
# 11   12.0  8923480.50

# %%
month_name = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
month['month_name']=month_name
changetype(month)
month.dtypes
plt.figure(figsize = (15, 15))
barlist=plt.bar(month['month_name'],month['sales'])

plt.title('month Wise Sales Graph')
plt.xlabel('month')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # Q2: Find the customer wise total_sale_price joining fact table and respective dimension table

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
#month are stored as number januray is 1 november is 11 and so on
select_stmt = "SELECT s.name, SUM(t.total_price) " \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.customer_dim s on s.customer_key=t.customer_key " \
"GROUP BY CUBE(s.name) " \
                "ORDER BY s.name"
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [('-', Decimal('20643.50')),
#  ('aafreen fatima', Decimal('11174.75')),
#  ('aafrin', Decimal('22136.75')),
#  ('aafrin @ dolly', Decimal('23529.75')),
#  ('aaftaab husan', Decimal('9682.00')),
#  ('aakanksha', Decimal('11469.00')),
#  ('aaliya', Decimal('21663.25')),
#  ('aamina', Decimal('12649.25')),
#  ('aamir', Decimal('10134.00')),
#  ('aamir hussain', Decimal('10892.50')),
#  ('aamod & pramod', Decimal('12280.25')),
#  ('aamrin jahan', Decimal('11622.00')),
#  ('aanamika misra', Decimal('8929.25')),
#  ('aanchal', Decimal('35703.50')),
#  ('aanik with her son', Decimal('8568.25')),
#  ('aansi devi', Decimal('9909.00')),
#  ('aanya @ china', Decimal('11443.50')),
#  ('aaradhana @ priyanka', Decimal('11469.25')),
#  ('aarifa bano', Decimal('11295.75')),
#  ('aarifun bivi', Decimal('13139.25')),
#  ('aarti', Decimal('661675.25')),
#  ('aarti @ kajal', Decimal('12108.50')),
#  ('aarti @ noni', Decimal('12335.50')),
# ...

# %%
customer= pd.DataFrame(list(records), columns=['name', 'sales'])
customer
customer=customer.dropna()
customer
# Out:
#                 name     sales
# 0                  -  20643.50
# 1     aafreen fatima  11174.75
# 2             aafrin  22136.75
# 3     aafrin @ dolly  23529.75
# 4      aaftaab husan   9682.00
# ...              ...       ...
# 4532           बबीता  10509.75
# 4533           मन्जू  10575.75
# 4534            माया   9862.50
# 4535            सरोज  11280.00
# 4536          सानिया  11010.00
#
# [4537 rows x 2 columns]

# %%
customer.dtypes
# Out:
# name     object
# sales    object
# dtype: object

# %%
customerSort=customer
#mane sales wise sort korchi 
customerSort.sort_values(by=["sales"],inplace=True,ascending=False)
customerSort
# Out:
#                 name       sales
# 2524           pooja  2109800.75
# 1201           jyoti  1331696.25
# 2272            neha   996121.00
# 4181          sunita   915543.75
# 2563          poonam   914285.25
# ...              ...         ...
# 74    ahsamin @ juhi     7554.25
# 3854      smt sujata     7496.25
# 1941         meenaxi     7113.50
# 397          bahwana     7105.50
# 2705           purva     7081.75
#
# [4537 rows x 2 columns]

# %%
changetype(customerSort)
customerDataFrame=customerSort[0:10]

# %%
x=customerDataFrame.nlargest(1, 'sales').values
print('Customer '+str(x[::,0])+' has highest purchase ')
# Out:
# Customer ['pooja'] has highest purchase

# %%
print('Customer '+str(x[::,0])+' has highest purchase of '+str(x[::,1]),'taka')
# Out:
# Customer ['pooja'] has highest purchase of [2109800.75] taka

# %%
df=customer[0:20]
df=df.set_index(['name'])
df
# Out:
#                sales
# name
# pooja     2109800.75
# jyoti     1331696.25
# neha       996121.00
# sunita     915543.75
# poonam     914285.25
# priyanka   819243.25
# seema      813087.75
# suman      748327.25
# komal      698672.75
# mamta      688649.50
# nisha      685782.25
# rekha      667550.00
# kajal      662696.50
# aarti      661675.25
# kavita     637166.25
# laxmi      629878.25
# manisha    604706.50
# pinki      592340.75
# preeti     591862.75
# anita      585949.50

# %% [markdown]
# # Q2: Find the bank wise total_sale_price joining fact table and respective dimension table

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT s.bank_name, SUM(t.total_price) " \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.trans_dim s on s.payment_key=t.payment_key " \
                "GROUP BY CUBE(s.bank_name) " \
                "ORDER BY s.bank_name "
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [('AB Bank Limited', Decimal('2728515.50')),
#  ('Bangladesh Commerce Bank Limited', Decimal('2730999.25')),
#  ('Bank Asia Limited', Decimal('2687142.75')),
#  ('Bengal Commercial Bank Ltd', Decimal('2704554.25')),
#  ('Bkash', Decimal('2689352.50')),
#  ('BRAC Bank Limited', Decimal('2705795.75')),
#  ('Citizens Bank Limited', Decimal('2723215.25')),
#  ('City Bank Limited', Decimal('2713952.50')),
#  ('Community Bank Bangladesh Limited', Decimal('2685751.50')),
#  ('Dhaka Bank Limited', Decimal('2728366.00')),
#  ('Dutch-Bangla Bank Limited', Decimal('2692435.25')),
#  ('Eastern Bank Limited', Decimal('2687182.25')),
#  ('IFIC Bank Limited', Decimal('2699759.75')),
#  ('Jamuna Bank Limited', Decimal('2689886.50')),
#  ('Meghna Bank Limited', Decimal('2700528.50')),
#  ('Mercantile Bank Limited', Decimal('2676578.50')),
#  ('Midland Bank Limited', Decimal('2688430.25')),
#  ('Modhumoti Bank Limited', Decimal('2715279.00')),
# ...

# %%
df_bank = pd.DataFrame(records, columns=['bank_name', 'sales'])
df_bank
# Out:
#                                             bank_name         sales
# 0                                     AB Bank Limited    2728515.50
# 1                    Bangladesh Commerce Bank Limited    2730999.25
# 2                                   Bank Asia Limited    2687142.75
# 3                          Bengal Commercial Bank Ltd    2704554.25
# 4                                               Bkash    2689352.50
# 5                                   BRAC Bank Limited    2705795.75
# 6                               Citizens Bank Limited    2723215.25
# 7                                   City Bank Limited    2713952.50
# 8                   Community Bank Bangladesh Limited    2685751.50
# 9                                  Dhaka Bank Limited    2728366.00
# 10                          Dutch-Bangla Bank Limited    2692435.25
# 11                               Eastern Bank Limited    2687182.25
# 12                                  IFIC Bank Limited    2699759.75
# ...

# %%
#dropna() funtion is used to remove nan rows
df_bank=df_bank.dropna()
df_bank
# Out:
#                                                          sales
# bank_name
# AB Bank Limited                                     2728515.50
# Bangladesh Commerce Bank Limited                    2730999.25
# Bank Asia Limited                                   2687142.75
# Bengal Commercial Bank Ltd                          2704554.25
# Bkash                                               2689352.50
# BRAC Bank Limited                                   2705795.75
# Citizens Bank Limited                               2723215.25
# City Bank Limited                                   2713952.50
# Community Bank Bangladesh Limited                   2685751.50
# Dhaka Bank Limited                                  2728366.00
# Dutch-Bangla Bank Limited                           2692435.25
# Eastern Bank Limited                                2687182.25
# IFIC Bank Limited                                   2699759.75
# Jamuna Bank Limited                                 2689886.50
# ...

# %%
df_bank.dtypes
changetype(df_bank)
df_bank.dtypes
# Out:
# sales    float64
# dtype: object

# %% [markdown]
# # Q2: Find the transaction(cash/online) wise total_sale_price joining fact table and respective dimension table

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT s.trans_type, SUM(t.total_price) " \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.trans_dim s on s.payment_key=t.payment_key " \
                "GROUP BY CUBE(s.trans_type) " \
                "ORDER BY s.trans_type "
cur.execute(select_stmt)
records = cur.fetchall()
# Out:
# successfully connected to database

# %%
records
# Out:
# [('card', Decimal('94583038.50')),
#  ('cash', Decimal('2708515.75')),
#  ('mobile', Decimal('8109881.50')),
#  (None, Decimal('105401435.75'))]

# %%
df_q1 = pd.DataFrame(records, columns=['trans_type', 'sales'])
df_q1=df_q1.dropna()
df_q1
# Out:
#   trans_type        sales
# 0       card  94583038.50
# 1       cash   2708515.75
# 2     mobile   8109881.50

# %%
changetype(df_q1)
df_q1
df_q1=df_q1.set_index(['trans_type'])
df_q1
df_q1.plot.pie(y='sales')
# Out:
# <Axes: ylabel='sales'>

# %% [markdown]
# # Q3: Total sales in Barisal

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT s.division, SUM(t.total_price) " \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.store_dim s on s.store_key=t.store_key " \
"WHERE s.division='BARISAL'"\
                "GROUP BY CUBE(s.division) " \
                "ORDER BY s.division "
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [('BARISAL', Decimal('7520343.75')), (None, Decimal('7520343.75'))]

# %%
df_q1 = pd.DataFrame(list(records), columns=['division', 'sales'])
df_q1=df_q1.dropna()

# %%
df_q1
# Out:
#   division       sales
# 0  BARISAL  7520343.75

# %% [markdown]
# # Q4: Total sales in 2015

# %%
#Now we want to sort by year wise 
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT s.year, SUM(t.total_price) " \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.time_dim s on s.time_key=t.time_key " \
                "WHERE s.year='2015'"\
                "GROUP BY CUBE(s.year) " \
                "ORDER BY s.year "
cur.execute(select_stmt)
records = cur.fetchall()
# Out:
# successfully connected to database

# %%
records
# Out:
# [(2015, Decimal('15095720.25')), (None, Decimal('15095720.25'))]

# %%
df_q1 = pd.DataFrame(list(records), columns=['division', 'sales'])
df_q1=df_q1.dropna()
df_q1
# Out:
#    division        sales
# 0    2015.0  15095720.25

# %% [markdown]
# # Q5: Total sales of Barisal in 2015

# %%
#Now we want to sort by year wise 
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT tt.year, s.division, SUM(t.total_price)" \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.time_dim tt on tt.time_key=t.time_key " \
            "JOIN ecomdb_star_schema.store_dim s ON s.store_key=t.store_key "\
            "WHERE tt.year = 2015 and s.division = 'BARISAL'"\
                "GROUP BY CUBE(tt.year, s.division) "
cur.execute(select_stmt)
records = cur.fetchall()
# Out:
# successfully connected to database

# %%
records
# Out:
# [(2015, 'BARISAL', Decimal('1076902.75')),
#  (2015, None, Decimal('1076902.75')),
#  (None, None, Decimal('1076902.75')),
#  (None, 'BARISAL', Decimal('1076902.75'))]

# %%
df_q1 = pd.DataFrame(records, columns=['year', 'division', 'sales'])
df_q1.dropna()
# Out:
#      year division       sales
# 0  2015.0  BARISAL  1076902.75

# %% [markdown]
# # Q6: For each store(item supplier), what are the top three products offered that are most often purchased?
#
#     S1-> item1 -> quantity_sales
#
#     S1-> item2 -> quantity_sales
#
#     S1-> item3 -> quantity_sales

# %%
#for each store I will just keep the products in decending oder of the purchase, 
#then with help of python library i will pick top three

#firstly, sort with store key, if tie then sort with sum of t.quantity 

con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT s.store_key, it.item_name ,SUM(t.quantity) " \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.store_dim s on s.store_key=t.store_key "\
            "JOIN ecomdb_star_schema.item_dim it on it.item_key=t.item_key "\
                "GROUP BY CUBE(s.store_key, it.item_name) " \
                "ORDER BY s.store_key, SUM(t.quantity) desc"
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [('S0001', None, Decimal('8169')),
#  ('S0001', 'Pepsi - 12 oz cans', Decimal('92')),
#  ('S0001', 'Muscle Milk Protein Shake Van. 11oz', Decimal('90')),
#  ('S0001', 'Hefty Supreme Foam Plates 6 inch', Decimal('78')),
#  ('S0001', 'Waterloo Sparkling Lime 12oz', Decimal('70')),
#  ('S0001', 'Njoy Sugar Canister 22 oz', Decimal('69')),
#  ('S0001', 'Vita Coconut Water 10oz ', Decimal('68')),
#  ('S0001', 'Muscle Milk Protein Shake Strbry. 11oz', Decimal('67')),
#  ('S0001', 'Sprite - 12 oz cans', Decimal('64')),
#  ('S0001', 'Cheez It White Cheddar 1.5 oz', Decimal('63')),
#  ('S0001', 'Sargento Bal. Breaks (fruit, nut, cheese)', Decimal('62')),
#  ('S0001', 'Dixie Perfecttouch Paper Cups 12oz', Decimal('61')),
#  ('S0001', 'Hershey Chocoalte Minatures Assort.', Decimal('60')),
#  ('S0001', 'A&W Root Beer - 12 oz cans', Decimal('60')),
#  ('S0001', 'Dark Chocolate Mint Patties', Decimal('60')),
# ...

# %%
df_q1 = pd.DataFrame(records, columns=['store_id', 'item_name', 'quantity'])
df_q1=df_q1.dropna()
#per one store top 3 are taking
#per store id theke 3 ta 3 ta kore nibo
df_q1=df_q1.groupby('store_id').head(3)
df_q1
# Out:
#        store_id                                item_name quantity
# 1         S0001                       Pepsi - 12 oz cans       92
# 2         S0001      Muscle Milk Protein Shake Van. 11oz       90
# 3         S0001         Hefty Supreme Foam Plates 6 inch       78
# 259       S0002             Planters Nut-trition 1.5 oz        83
# 260       S0002              Altoids Small Packs Variety       80
# ...         ...                                      ...      ...
# 187322    S0098  Cliff Builders Protein Bar Variety Pack       84
# 187323    S0098                       Pepsi - 12 oz cans       79
# 187581    S0099                       Pepsi - 12 oz cans       93
# 187582    S0099                   Diet Coke - 12 oz cans       87
# 187583    S0099    Coffee-mate Original Powdered Creamer       86
#
# [2178 rows x 3 columns]

# %% [markdown]
# # Q7: What products have been sold through card or mobile since X days?
#
#     input: X = 5 days
#
#     output: [item1, item2, item3, ...........]

# %%
x=input('Give number of days ')
# Out:
# Give number of days 857

# %%
#product time transaction
#WHERE tt.t_date>(CURRENT_DATE -'857 days'::interval) 
#this will make familiar 857 days to sql; this means 857 days is a time interval 

con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = '''SELECT it.item_name, tt.t_date 
              FROM ecomdb_star_schema.fact_table t 
            JOIN ecomdb_star_schema.item_dim it ON it.item_key=t.item_key 
            JOIN ecomdb_star_schema.trans_dim tr ON tr.payment_key=t.payment_key 
              JOIN ecomdb_star_schema.time_dim tt on tt.time_key=t.time_key 
                WHERE tt.t_date>(CURRENT_DATE -' 
                '''
                
stmt=str(x)+" days'::interval) AND tr.trans_type='card'" 
newstmt = select_stmt + stmt

                
cur.execute(newstmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [('Planters Nut-trition 1.5 oz ', datetime.date(2021, 1, 23)),
#  ('Cheese and Peanut Butter Crackers', datetime.date(2021, 1, 23)),
#  ('Clorox Disinfecting Wipes ', datetime.date(2021, 1, 23)),
#  ('Crunchy Granola Bars Oats & Honey', datetime.date(2021, 1, 23)),
#  ('Go-Gurt Low Fat Yogurt, Strwbry & Berry ', datetime.date(2021, 1, 23)),
#  ('Coke Classic 12 oz cans', datetime.date(2021, 1, 23)),
#  ('Quaker Instant Oatmeal Variety ', datetime.date(2021, 1, 23)),
#  ('Cascade Gel w/ Dawn Dishwasher', datetime.date(2021, 1, 23)),
#  ('Frito Fiesta Flavors Variety', datetime.date(2021, 1, 23)),
#  ('Plastic Knives White  Heavyweight', datetime.date(2021, 1, 23)),
#  ('Foam Coffee Cups - 12 ounce', datetime.date(2021, 1, 23)),
#  ('Hefty Supreme Foam Bowls 12oz', datetime.date(2021, 1, 23)),
#  ('Dark Chocolate Mint Patties', datetime.date(2021, 1, 23)),
#  ('Plastic Spoons White  Heavyweight', datetime.date(2021, 1, 23)),
# ...

# %% [markdown]
# # Q8: What season(quarter) is the worst for each product item? As example,
#
#        item1-> q1
#
#        item2-> q2

# %%
#for each store I will just keep the products in decending oder of the purchase, 
#then with help of python library i will pick top three

#firstly, sort with store key, if tie then sort with sum of t.quantity 

con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT tim.quarter, it.item_name ,SUM(t.total_price) " \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.item_dim it on it.item_key=t.item_key "\
            "JOIN ecomdb_star_schema.time_dim tim on tim.time_key=t.time_key "\
                "GROUP BY CUBE(it.item_name, tim.quarter) " \
                "ORDER BY it.item_name, SUM(t.total_price) "
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [('Q1', '100% Juice Box Variety 6.75 oz ', Decimal('5698')),
#  ('Q4', '100% Juice Box Variety 6.75 oz ', Decimal('5806')),
#  ('Q2', '100% Juice Box Variety 6.75 oz ', Decimal('5876')),
#  ('Q3', '100% Juice Box Variety 6.75 oz ', Decimal('6045')),
#  (None, '100% Juice Box Variety 6.75 oz ', Decimal('23425')),
#  ('Q2', 'A&W Root Beer - 12 oz cans', Decimal('5735')),
#  ('Q4', 'A&W Root Beer - 12 oz cans', Decimal('5820')),
#  ('Q1', 'A&W Root Beer - 12 oz cans', Decimal('5965')),
#  ('Q3', 'A&W Root Beer - 12 oz cans', Decimal('6103')),
#  (None, 'A&W Root Beer - 12 oz cans', Decimal('23623')),
#  ('Q4', 'A&W Root Beer Diet - 12 oz cans', Decimal('5589')),
#  ('Q2', 'A&W Root Beer Diet - 12 oz cans', Decimal('5627')),
#  ('Q3', 'A&W Root Beer Diet - 12 oz cans', Decimal('5940')),
#  ('Q1', 'A&W Root Beer Diet - 12 oz cans', Decimal('6026')),
#  (None, 'A&W Root Beer Diet - 12 oz cans', Decimal('23182')),
# ...

# %%
df_q1 = pd.DataFrame(records, columns=['quarter', 'item_name', 'quantity'])
df_q1=df_q1.dropna()
#from per item we will pick one
df_q1=df_q1.groupby('item_name').head(1)
df_q1
# Out:
#      quarter                              item_name quantity
# 0         Q1        100% Juice Box Variety 6.75 oz      5698
# 5         Q2             A&W Root Beer - 12 oz cans     5735
# 10        Q4        A&W Root Beer Diet - 12 oz cans     5589
# 15        Q1                   Advil 2 pill packets     5453
# 20        Q1          All Purpose Cleaner 409 Spray     5325
# ...      ...                                    ...      ...
# 1270      Q2        Welch's 100% Juice Variety10 oz     5494
# 1275      Q1     Wint O Green LifeSavers Sugar Free     5323
# 1280      Q1        Wonderful Pistachios (in shell)     5578
# 1285      Q1  Yoplait Original Yogurt Variety Pack      5426
# 1290      Q1            Zoo Animal Cookies/Crackers     5462
#
# [259 rows x 3 columns]

# %% [markdown]
# # Q9: Break down the total sales of items geographically (division-wise).
#
#      item1-> division1->total_sales
#
#      item1-> division2->total_sales

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT it.item_name , s.division, SUM(t.total_price) " \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.item_dim it on it.item_key=t.item_key "\
            "JOIN ecomdb_star_schema.store_dim s on s.store_key=t.store_key "\
                "GROUP BY CUBE(it.item_name, s.division) " \
                "ORDER BY it.item_name, s.division "
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [('100% Juice Box Variety 6.75 oz ', 'BARISAL', Decimal('1586')),
#  ('100% Juice Box Variety 6.75 oz ', 'CHITTAGONG', Decimal('4330')),
#  ('100% Juice Box Variety 6.75 oz ', 'DHAKA', Decimal('9413')),
#  ('100% Juice Box Variety 6.75 oz ', 'KHULNA', Decimal('2517')),
#  ('100% Juice Box Variety 6.75 oz ', 'RAJSHAHI', Decimal('2582')),
#  ('100% Juice Box Variety 6.75 oz ', 'RANGPUR', Decimal('1779')),
#  ('100% Juice Box Variety 6.75 oz ', 'SYLHET', Decimal('1218')),
#  ('100% Juice Box Variety 6.75 oz ', None, Decimal('23425')),
#  ('A&W Root Beer - 12 oz cans', 'BARISAL', Decimal('1661')),
#  ('A&W Root Beer - 12 oz cans', 'CHITTAGONG', Decimal('4527')),
#  ('A&W Root Beer - 12 oz cans', 'DHAKA', Decimal('9346')),
#  ('A&W Root Beer - 12 oz cans', 'KHULNA', Decimal('2468')),
#  ('A&W Root Beer - 12 oz cans', 'RAJSHAHI', Decimal('2417')),
#  ('A&W Root Beer - 12 oz cans', 'RANGPUR', Decimal('1878')),
# ...

# %%
df_q1 = pd.DataFrame(records, columns=['item_name', 'division', 'quantity'])
df_q1=df_q1.dropna()
#from per item we will pick one
#df_q1=df_q1.groupby('item_name').head(1)
df_q1
# Out:
#                             item_name    division quantity
# 0     100% Juice Box Variety 6.75 oz      BARISAL     1586
# 1     100% Juice Box Variety 6.75 oz   CHITTAGONG     4330
# 2     100% Juice Box Variety 6.75 oz        DHAKA     9413
# 3     100% Juice Box Variety 6.75 oz       KHULNA     2517
# 4     100% Juice Box Variety 6.75 oz     RAJSHAHI     2582
# ...                               ...         ...      ...
# 2066      Zoo Animal Cookies/Crackers       DHAKA     8449
# 2067      Zoo Animal Cookies/Crackers      KHULNA     2531
# 2068      Zoo Animal Cookies/Crackers    RAJSHAHI     2650
# 2069      Zoo Animal Cookies/Crackers     RANGPUR     1799
# 2070      Zoo Animal Cookies/Crackers      SYLHET     1052
#
# [1813 rows x 3 columns]

# %% [markdown]
# # Q10: What are the average sales of products sales per store monthly?
#
#      S1->M1-> avg_sales
#
#            s1-> M2 -> avg_sales

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()
select_stmt = "SELECT s.store_key , tim.month, AVG(t.total_price) " \
              "FROM ecomdb_star_schema.fact_table t " \
              "JOIN ecomdb_star_schema.time_dim tim on tim.time_key=t.time_key "\
            "JOIN ecomdb_star_schema.store_dim s on s.store_key=t.store_key "\
                "GROUP BY CUBE(s.store_key, tim.month) " \
                "ORDER BY s.store_key, tim.month "
cur.execute(select_stmt)
records = cur.fetchall()
records
# Out:
# successfully connected to database
# [('S0001', 1, Decimal('97.7543103448275862')),
#  ('S0001', 2, Decimal('100.5776699029126214')),
#  ('S0001', 3, Decimal('109.4158878504672897')),
#  ('S0001', 4, Decimal('98.8805309734513274')),
#  ('S0001', 5, Decimal('99.5245535714285714')),
#  ('S0001', 6, Decimal('101.2459349593495935')),
#  ('S0001', 7, Decimal('103.9189189189189189')),
#  ('S0001', 8, Decimal('105.1269531250000000')),
#  ('S0001', 9, Decimal('96.1901041666666667')),
#  ('S0001', 10, Decimal('104.6166666666666667')),
#  ('S0001', 11, Decimal('103.8355855855855856')),
#  ('S0001', 12, Decimal('107.8697478991596639')),
#  ('S0001', None, Decimal('102.5407569141193595')),
#  ('S0002', 1, Decimal('98.2902684563758389')),
#  ('S0002', 2, Decimal('106.3849557522123894')),
#  ('S0002', 3, Decimal('102.7565217391304348')),
#  ('S0002', 4, Decimal('104.0798969072164948')),
#  ('S0002', 5, Decimal('109.1587591240875912')),
#  ('S0002', 6, Decimal('100.9268867924528302')),
# ...

# %%
df_q1 = pd.DataFrame(records, columns=['store_key', 'month', 'total_avg_price'])
df_q1=df_q1.dropna()
#from per item we will pick one
#df_q1=df_q1.groupby('item_name').head(1)
df_q1
# Out:
#      store_key  month       total_avg_price
# 0        S0001    1.0   97.7543103448275862
# 1        S0001    2.0  100.5776699029126214
# 2        S0001    3.0  109.4158878504672897
# 3        S0001    4.0   98.8805309734513274
# 4        S0001    5.0   99.5245535714285714
# ...        ...    ...                   ...
# 9432     S0099    8.0   96.2933673469387755
# 9433     S0099    9.0  114.1365740740740741
# 9434     S0099   10.0  102.7897727272727273
# 9435     S0099   11.0  107.3810679611650485
# 9436     S0099   12.0  102.9014423076923077
#
# [8712 rows x 3 columns]
